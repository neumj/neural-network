# %% [markdown]
# ### Adapted from Coursera Deep Learning Speciality: Improving Deep Neural Networks: Hyperparameter tuning, regularization, optimization
#
# #### Initializations
#
# #### offered by deeplearning.ai

# %%
import numpy as np
import matplotlib.pyplot as plt
from deepnn import io
from deepnn import models
from deepnn import predict

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
# load image dataset: blue/red dots in circles
train_X, train_Y, test_X, test_Y = io.generate_donut_dataset()

# %%
L_dims = [train_X.shape[0], 10, 5, 1]

# %%
#initialization options: zeros, random, he, deep
init = "he"
parameters = models.L_layer_model(train_X, train_Y, L_dims, learning_rate=0.01, num_iterations=15000, print_cost=True, initialization = init)
# Out:
# Cost after iteration 0: 0.706354
# Cost after iteration 1000: 0.684167
# Cost after iteration 2000: 0.674301
# Cost after iteration 3000: 0.659983
# Cost after iteration 4000: 0.626547
# Cost after iteration 5000: 0.569667
# Cost after iteration 6000: 0.485241
# Cost after iteration 7000: 0.383805
# Cost after iteration 8000: 0.293448
# Cost after iteration 9000: 0.227764
# Cost after iteration 10000: 0.183286
# Cost after iteration 11000: 0.153430
# Cost after iteration 12000: 0.134161
# Cost after iteration 13000: 0.119932
# Cost after iteration 14000: 0.093236

# %%
print ("On the train set:")
predictions_train = predict.predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict.predict(test_X, test_Y, parameters)
# Out:
# On the train set:
# Accuracy: 0.9800000000000001
# On the test set:
# Accuracy: 0.94

# %%
plt.title("Model with {init} initialization".format(init=init))
axes = plt.gca()
axes.set_xlim([-1.5,1.5])
axes.set_ylim([-1.5,1.5])
io.plot_decision_boundary(lambda x: predict.predict_dec(parameters, x.T), train_X, train_Y)
